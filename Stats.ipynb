# %%
library(tidyverse)

participant_data <- dir("./data", full.names = T) %>% map_df(
  ~read_csv(., col_types = cols_only(
    participantId = col_double(),
    condition = col_double(),
    trialNumber = col_double(),
    trialStart = col_double(),
    trialEnd = col_double(),
    expectedAngle = col_double(),
    drawnAngle = col_double(),
    wristRotation = col_double()
  )
  )
)

participant_data
# Out:
# Warning message:
# “100 parsing failures.
# row col  expected    actual                    file
#   1  -- 9 columns 8 columns './data/101_021733.csv'
#   2  -- 9 columns 8 columns './data/101_021733.csv'
#   3  -- 9 columns 8 columns './data/101_021733.csv'
#   4  -- 9 columns 8 columns './data/101_021733.csv'
#   5  -- 9 columns 8 columns './data/101_021733.csv'
# ... ... ......... ......... .......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                    file
#   1  -- 9 columns 8 columns './data/102_021734.csv'
#   2  -- 9 columns 8 columns './data/102_021734.csv'
#   3  -- 9 columns 8 columns './data/102_021734.csv'
#   4  -- 9 columns 8 columns './data/102_021734.csv'
#   5  -- 9 columns 8 columns './data/102_021734.csv'
# ... ... ......... ......... .......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                    file
#   1  -- 9 columns 8 columns './data/111_021735.csv'
#   2  -- 9 columns 8 columns './data/111_021735.csv'
#   3  -- 9 columns 8 columns './data/111_021735.csv'
#   4  -- 9 columns 8 columns './data/111_021735.csv'
#   5  -- 9 columns 8 columns './data/111_021735.csv'
# ... ... ......... ......... .......................
# See problems(...) for more details.
# ”
# Warning message:
# “129 parsing failures.
# row col  expected    actual                    file
#   1  -- 9 columns 8 columns './data/112_021736.csv'
#   2  -- 9 columns 8 columns './data/112_021736.csv'
#   3  -- 9 columns 8 columns './data/112_021736.csv'
#   4  -- 9 columns 8 columns './data/112_021736.csv'
#   5  -- 9 columns 8 columns './data/112_021736.csv'
# ... ... ......... ......... .......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                   file
#   1  -- 9 columns 8 columns './data/11_021709.csv'
#   2  -- 9 columns 8 columns './data/11_021709.csv'
#   3  -- 9 columns 8 columns './data/11_021709.csv'
#   4  -- 9 columns 8 columns './data/11_021709.csv'
#   5  -- 9 columns 8 columns './data/11_021709.csv'
# ... ... ......... ......... ......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                    file
#   1  -- 9 columns 8 columns './data/121_021736.csv'
#   2  -- 9 columns 8 columns './data/121_021736.csv'
#   3  -- 9 columns 8 columns './data/121_021736.csv'
#   4  -- 9 columns 8 columns './data/121_021736.csv'
#   5  -- 9 columns 8 columns './data/121_021736.csv'
# ... ... ......... ......... .......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                    file
#   1  -- 9 columns 8 columns './data/122_021737.csv'
#   2  -- 9 columns 8 columns './data/122_021737.csv'
#   3  -- 9 columns 8 columns './data/122_021737.csv'
#   4  -- 9 columns 8 columns './data/122_021737.csv'
#   5  -- 9 columns 8 columns './data/122_021737.csv'
# ... ... ......... ......... .......................
# See problems(...) for more details.
# ”
# Warning message:
# “94 parsing failures.
# row col  expected    actual                   file
#   1  -- 9 columns 8 columns './data/12_021714.csv'
#   2  -- 9 columns 8 columns './data/12_021714.csv'
#   3  -- 9 columns 8 columns './data/12_021714.csv'
#   4  -- 9 columns 8 columns './data/12_021714.csv'
#   5  -- 9 columns 8 columns './data/12_021714.csv'
# ... ... ......... ......... ......................
# See problems(...) for more details.
# ”
# Warning message:
# “106 parsing failures.
# row col  expected    actual                    file
#   1  -- 9 columns 8 columns './data/131_021738.csv'
#   2  -- 9 columns 8 columns './data/131_021738.csv'
#   3  -- 9 columns 8 columns './data/131_021738.csv'
#   4  -- 9 columns 8 columns './data/131_021738.csv'
#   5  -- 9 columns 8 columns './data/131_021738.csv'
# ... ... ......... ......... .......................
# See problems(...) for more details.
# ”
# Warning message:
# “101 parsing failures.
# row col  expected    actual                    file
#   1  -- 9 columns 8 columns './data/132_021739.csv'
#   2  -- 9 columns 8 columns './data/132_021739.csv'
#   3  -- 9 columns 8 columns './data/132_021739.csv'
#   4  -- 9 columns 8 columns './data/132_021739.csv'
#   5  -- 9 columns 8 columns './data/132_021739.csv'
# ... ... ......... ......... .......................
# See problems(...) for more details.
# ”
# Warning message:
# “101 parsing failures.
# row col  expected    actual                    file
#   1  -- 9 columns 8 columns './data/141_021740.csv'
#   2  -- 9 columns 8 columns './data/141_021740.csv'
#   3  -- 9 columns 8 columns './data/141_021740.csv'
#   4  -- 9 columns 8 columns './data/141_021740.csv'
#   5  -- 9 columns 8 columns './data/141_021740.csv'
# ... ... ......... ......... .......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                    file
#   1  -- 9 columns 8 columns './data/142_021741.csv'
#   2  -- 9 columns 8 columns './data/142_021741.csv'
#   3  -- 9 columns 8 columns './data/142_021741.csv'
#   4  -- 9 columns 8 columns './data/142_021741.csv'
#   5  -- 9 columns 8 columns './data/142_021741.csv'
# ... ... ......... ......... .......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                    file
#   1  -- 9 columns 8 columns './data/151_021742.csv'
#   2  -- 9 columns 8 columns './data/151_021742.csv'
#   3  -- 9 columns 8 columns './data/151_021742.csv'
#   4  -- 9 columns 8 columns './data/151_021742.csv'
#   5  -- 9 columns 8 columns './data/151_021742.csv'
# ... ... ......... ......... .......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                    file
#   1  -- 9 columns 8 columns './data/152_021743.csv'
#   2  -- 9 columns 8 columns './data/152_021743.csv'
#   3  -- 9 columns 8 columns './data/152_021743.csv'
#   4  -- 9 columns 8 columns './data/152_021743.csv'
#   5  -- 9 columns 8 columns './data/152_021743.csv'
# ... ... ......... ......... .......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                    file
#   1  -- 9 columns 8 columns './data/161_021744.csv'
#   2  -- 9 columns 8 columns './data/161_021744.csv'
#   3  -- 9 columns 8 columns './data/161_021744.csv'
#   4  -- 9 columns 8 columns './data/161_021744.csv'
#   5  -- 9 columns 8 columns './data/161_021744.csv'
# ... ... ......... ......... .......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                    file
#   1  -- 9 columns 8 columns './data/162_021745.csv'
#   2  -- 9 columns 8 columns './data/162_021745.csv'
#   3  -- 9 columns 8 columns './data/162_021745.csv'
#   4  -- 9 columns 8 columns './data/162_021745.csv'
#   5  -- 9 columns 8 columns './data/162_021745.csv'
# ... ... ......... ......... .......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                    file
#   1  -- 9 columns 8 columns './data/171_021746.csv'
#   2  -- 9 columns 8 columns './data/171_021746.csv'
#   3  -- 9 columns 8 columns './data/171_021746.csv'
#   4  -- 9 columns 8 columns './data/171_021746.csv'
#   5  -- 9 columns 8 columns './data/171_021746.csv'
# ... ... ......... ......... .......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                    file
#   1  -- 9 columns 8 columns './data/172_021747.csv'
#   2  -- 9 columns 8 columns './data/172_021747.csv'
#   3  -- 9 columns 8 columns './data/172_021747.csv'
#   4  -- 9 columns 8 columns './data/172_021747.csv'
#   5  -- 9 columns 8 columns './data/172_021747.csv'
# ... ... ......... ......... .......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                    file
#   1  -- 9 columns 8 columns './data/181_021748.csv'
#   2  -- 9 columns 8 columns './data/181_021748.csv'
#   3  -- 9 columns 8 columns './data/181_021748.csv'
#   4  -- 9 columns 8 columns './data/181_021748.csv'
#   5  -- 9 columns 8 columns './data/181_021748.csv'
# ... ... ......... ......... .......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                    file
#   1  -- 9 columns 8 columns './data/182_021749.csv'
#   2  -- 9 columns 8 columns './data/182_021749.csv'
#   3  -- 9 columns 8 columns './data/182_021749.csv'
#   4  -- 9 columns 8 columns './data/182_021749.csv'
#   5  -- 9 columns 8 columns './data/182_021749.csv'
# ... ... ......... ......... .......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                    file
#   1  -- 9 columns 8 columns './data/191_021750.csv'
#   2  -- 9 columns 8 columns './data/191_021750.csv'
#   3  -- 9 columns 8 columns './data/191_021750.csv'
#   4  -- 9 columns 8 columns './data/191_021750.csv'
#   5  -- 9 columns 8 columns './data/191_021750.csv'
# ... ... ......... ......... .......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                    file
#   1  -- 9 columns 8 columns './data/192_021751.csv'
#   2  -- 9 columns 8 columns './data/192_021751.csv'
#   3  -- 9 columns 8 columns './data/192_021751.csv'
#   4  -- 9 columns 8 columns './data/192_021751.csv'
#   5  -- 9 columns 8 columns './data/192_021751.csv'
# ... ... ......... ......... .......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                    file
#   1  -- 9 columns 8 columns './data/201_021752.csv'
#   2  -- 9 columns 8 columns './data/201_021752.csv'
#   3  -- 9 columns 8 columns './data/201_021752.csv'
#   4  -- 9 columns 8 columns './data/201_021752.csv'
#   5  -- 9 columns 8 columns './data/201_021752.csv'
# ... ... ......... ......... .......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                    file
#   1  -- 9 columns 8 columns './data/202_021752.csv'
#   2  -- 9 columns 8 columns './data/202_021752.csv'
#   3  -- 9 columns 8 columns './data/202_021752.csv'
#   4  -- 9 columns 8 columns './data/202_021752.csv'
#   5  -- 9 columns 8 columns './data/202_021752.csv'
# ... ... ......... ......... .......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                   file
#   1  -- 9 columns 8 columns './data/21_021715.csv'
#   2  -- 9 columns 8 columns './data/21_021715.csv'
#   3  -- 9 columns 8 columns './data/21_021715.csv'
#   4  -- 9 columns 8 columns './data/21_021715.csv'
#   5  -- 9 columns 8 columns './data/21_021715.csv'
# ... ... ......... ......... ......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                   file
#   1  -- 9 columns 8 columns './data/22_021716.csv'
#   2  -- 9 columns 8 columns './data/22_021716.csv'
#   3  -- 9 columns 8 columns './data/22_021716.csv'
#   4  -- 9 columns 8 columns './data/22_021716.csv'
#   5  -- 9 columns 8 columns './data/22_021716.csv'
# ... ... ......... ......... ......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                   file
#   1  -- 9 columns 8 columns './data/31_021717.csv'
#   2  -- 9 columns 8 columns './data/31_021717.csv'
#   3  -- 9 columns 8 columns './data/31_021717.csv'
#   4  -- 9 columns 8 columns './data/31_021717.csv'
#   5  -- 9 columns 8 columns './data/31_021717.csv'
# ... ... ......... ......... ......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                   file
#   1  -- 9 columns 8 columns './data/32_021718.csv'
#   2  -- 9 columns 8 columns './data/32_021718.csv'
#   3  -- 9 columns 8 columns './data/32_021718.csv'
#   4  -- 9 columns 8 columns './data/32_021718.csv'
#   5  -- 9 columns 8 columns './data/32_021718.csv'
# ... ... ......... ......... ......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                   file
#   1  -- 9 columns 8 columns './data/41_021719.csv'
#   2  -- 9 columns 8 columns './data/41_021719.csv'
#   3  -- 9 columns 8 columns './data/41_021719.csv'
#   4  -- 9 columns 8 columns './data/41_021719.csv'
#   5  -- 9 columns 8 columns './data/41_021719.csv'
# ... ... ......... ......... ......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                   file
#   1  -- 9 columns 8 columns './data/42_021722.csv'
#   2  -- 9 columns 8 columns './data/42_021722.csv'
#   3  -- 9 columns 8 columns './data/42_021722.csv'
#   4  -- 9 columns 8 columns './data/42_021722.csv'
#   5  -- 9 columns 8 columns './data/42_021722.csv'
# ... ... ......... ......... ......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                   file
#   1  -- 9 columns 8 columns './data/51_021723.csv'
#   2  -- 9 columns 8 columns './data/51_021723.csv'
#   3  -- 9 columns 8 columns './data/51_021723.csv'
#   4  -- 9 columns 8 columns './data/51_021723.csv'
#   5  -- 9 columns 8 columns './data/51_021723.csv'
# ... ... ......... ......... ......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                   file
#   1  -- 9 columns 8 columns './data/52_021724.csv'
#   2  -- 9 columns 8 columns './data/52_021724.csv'
#   3  -- 9 columns 8 columns './data/52_021724.csv'
#   4  -- 9 columns 8 columns './data/52_021724.csv'
#   5  -- 9 columns 8 columns './data/52_021724.csv'
# ... ... ......... ......... ......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                   file
#   1  -- 9 columns 8 columns './data/61_021724.csv'
#   2  -- 9 columns 8 columns './data/61_021724.csv'
#   3  -- 9 columns 8 columns './data/61_021724.csv'
#   4  -- 9 columns 8 columns './data/61_021724.csv'
#   5  -- 9 columns 8 columns './data/61_021724.csv'
# ... ... ......... ......... ......................
# See problems(...) for more details.
# ”
# Warning message:
# “88 parsing failures.
# row col  expected    actual                   file
#   1  -- 9 columns 8 columns './data/62_021726.csv'
#   2  -- 9 columns 8 columns './data/62_021726.csv'
#   3  -- 9 columns 8 columns './data/62_021726.csv'
#   4  -- 9 columns 8 columns './data/62_021726.csv'
#   5  -- 9 columns 8 columns './data/62_021726.csv'
# ... ... ......... ......... ......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                   file
#   1  -- 9 columns 8 columns './data/71_021727.csv'
#   2  -- 9 columns 8 columns './data/71_021727.csv'
#   3  -- 9 columns 8 columns './data/71_021727.csv'
#   4  -- 9 columns 8 columns './data/71_021727.csv'
#   5  -- 9 columns 8 columns './data/71_021727.csv'
# ... ... ......... ......... ......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                   file
#   1  -- 9 columns 8 columns './data/72_021728.csv'
#   2  -- 9 columns 8 columns './data/72_021728.csv'
#   3  -- 9 columns 8 columns './data/72_021728.csv'
#   4  -- 9 columns 8 columns './data/72_021728.csv'
#   5  -- 9 columns 8 columns './data/72_021728.csv'
# ... ... ......... ......... ......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                   file
#   1  -- 9 columns 8 columns './data/81_021729.csv'
#   2  -- 9 columns 8 columns './data/81_021729.csv'
#   3  -- 9 columns 8 columns './data/81_021729.csv'
#   4  -- 9 columns 8 columns './data/81_021729.csv'
#   5  -- 9 columns 8 columns './data/81_021729.csv'
# ... ... ......... ......... ......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                   file
#   1  -- 9 columns 8 columns './data/82_021729.csv'
#   2  -- 9 columns 8 columns './data/82_021729.csv'
#   3  -- 9 columns 8 columns './data/82_021729.csv'
#   4  -- 9 columns 8 columns './data/82_021729.csv'
#   5  -- 9 columns 8 columns './data/82_021729.csv'
# ... ... ......... ......... ......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                   file
#   1  -- 9 columns 8 columns './data/91_021731.csv'
#   2  -- 9 columns 8 columns './data/91_021731.csv'
#   3  -- 9 columns 8 columns './data/91_021731.csv'
#   4  -- 9 columns 8 columns './data/91_021731.csv'
#   5  -- 9 columns 8 columns './data/91_021731.csv'
# ... ... ......... ......... ......................
# See problems(...) for more details.
# ”
# Warning message:
# “100 parsing failures.
# row col  expected    actual                   file
#   1  -- 9 columns 8 columns './data/92_021732.csv'
#   2  -- 9 columns 8 columns './data/92_021732.csv'
#   3  -- 9 columns 8 columns './data/92_021732.csv'
#   4  -- 9 columns 8 columns './data/92_021732.csv'
#   5  -- 9 columns 8 columns './data/92_021732.csv'
# ... ... ......... ......... ......................
# See problems(...) for more details.
# ”
#      participantId condition trialNumber trialStart   trialEnd
# 1    101           0          1          1.627226e+12 1.627226e+12
# 2    101           0          2          1.627226e+12 1.627226e+12
# 3    101           0          3          1.627226e+12 1.627226e+12
# 4    101           0          4          1.627226e+12 1.627226e+12
# 5    101           0          5          1.627226e+12 1.627226e+12
# 6    101           0          6          1.627226e+12 1.627226e+12
# 7    101           0          7          1.627226e+12 1.627226e+12
# 8    101           0          8          1.627226e+12 1.627226e+12
# 9    101           0          9          1.627226e+12 1.627226e+12
# 10   101           0         10          1.627226e+12 1.627226e+12
# 11   101           0         11          1.627226e+12 1.627226e+12
# 12   101           0         12          1.627226e+12 1.627226e+12
# 13   101           0         13          1.627226e+12 1.627226e+12
# 14   101           0         14          1.627226e+12 1.627226e+12
# 15   101           0         15          1.627226e+12 1.627226e+12
# 16   101           0         16          1.627226e+12 1.627226e+12
# 17   101           0         17          1.627226e+12 1.627226e+12
# 18   101           0         18          1.627226e+12 1.627226e+12
# 19   101           0         19          1.627226e+12 1.627226e+12
# 20   101           0         20          1.627226e+12 1.627226e+12
# 21   101           0         21          1.627226e+12 1.627226e+12
# 22   101           0         22          1.627226e+12 1.627226e+12
# 23   101           0         23          1.627226e+12 1.627226e+12
# 24   101           0         24          1.627226e+12 1.627226e+12
# 25   101           0         25          1.627226e+12 1.627226e+12
# 26   101           0         26          1.627226e+12 1.627226e+12
# 27   101           0         27          1.627226e+12 1.627226e+12
# 28   101           0         28          1.627226e+12 1.627226e+12
# 29   101           0         29          1.627226e+12 1.627226e+12
# 30   101           0         30          1.627226e+12 1.627226e+12
# ⋮    ⋮             ⋮         ⋮           ⋮            ⋮
# 3990 92            1         21          1.626959e+12 1.626959e+12
# 3991 92            1         22          1.626959e+12 1.626959e+12
# 3992 92            1         23          1.626959e+12 1.626959e+12
# 3993 92            1         24          1.626959e+12 1.626959e+12
# 3994 92            1         25          1.626959e+12 1.626959e+12
# 3995 92            1         26          1.626959e+12 1.626959e+12
# 3996 92            1         27          1.626959e+12 1.626959e+12
# 3997 92            1         28          1.626959e+12 1.626959e+12
# 3998 92            1         29          1.626959e+12 1.626959e+12
# 3999 92            1         30          1.626959e+12 1.626959e+12
# 4000 92            1         31          1.626959e+12 1.626959e+12
# 4001 92            1         32          1.626959e+12 1.626959e+12
# 4002 92            1         33          1.626959e+12 1.626959e+12
# 4003 92            1         34          1.626959e+12 1.626959e+12
# 4004 92            1         35          1.626959e+12 1.626959e+12
# 4005 92            1         36          1.626959e+12 1.626959e+12
# 4006 92            1         37          1.626959e+12 1.626959e+12
# 4007 92            1         38          1.626959e+12 1.626959e+12
# 4008 92            1         39          1.626959e+12 1.626959e+12
# 4009 92            1         40          1.626959e+12 1.626959e+12
# 4010 92            1         41          1.626959e+12 1.626959e+12
# 4011 92            1         42          1.626959e+12 1.626959e+12
# 4012 92            1         43          1.626959e+12 1.626959e+12
# 4013 92            1         44          1.626959e+12 1.626959e+12
# 4014 92            1         45          1.626959e+12 1.626959e+12
# 4015 92            1         46          1.626959e+12 1.626959e+12
# 4016 92            1         47          1.626959e+12 1.626959e+12
# 4017 92            1         48          1.626959e+12 1.626959e+12
# 4018 92            1         49          1.626959e+12 1.626959e+12
# 4019 92            1         50          1.626959e+12 1.626959e+12
#      expectedAngle drawnAngle wristRotation
# 1      72            79        86
# 2     180          -137        85
# 3     180           180        88
# 4     108           136        91
# 5    -144          -130       112
# 6     -36           -44        81
# 7     -36             3        92
# 8     -72           -46        82
# 9      72            80       102
# 10   -108           -53        73
# 11      0            39        91
# 12     36            61        77
# 13   -108           -92        88
# 14   -144          -135        92
# 15      0            22        92
# 16   -144          -121        75
# 17    -36             8        89
# 18      0             1        76
# 19      0            38       107
# 20    144           135        77
# 21   -108          -133        79
# 22   -108           -90        81
# 23    108           115        83
# 24    -72           -67        74
# 25     36            38       126
# 26      0             6        89
# 27    144           144        79
# 28    180          -159        78
# 29    144          -178        75
# 30    180          -152        92
# ⋮    ⋮             ⋮          ⋮
# 3990 -145          -161        -1
# 3991   22            12       -14
# 3992  -48           -94        24
# 3993    0           -45        36
# 3994  -41           -86        -5
# 3995   73            25         1
# 3996   -1             5        -1
# 3997    1             3         1
# 3998   70            25        -2
# 3999   36            11         0
# 4000  111           180       -33
# 4001   82           144       -26
# 4002  -63          -155         9
# 4003  115           128         7
# 4004  -29           -71         7
# 4005 -122          -123       -14
# 4006   21            17       -15
# 4007  130           137       -14
# 4008   21            24       -15
# 4009   94            84       -14
# 4010  142            60        -2
# 4011   -6           -25        -6
# 4012  -42           -66        -6
# 4013  174          -147        -6
# 4014  128           140       -16
# 4015  -59          -126       -23
# 4016  164           180       -16
# 4017  -82          -153       -10
# 4018  -85          -133       -13
# 4019    5           -28         5
